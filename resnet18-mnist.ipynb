# %%
from model.resnet import *
from data_utils import *
from solver import *

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

# %%
device = torch.device('cuda')
dtype = torch.float32

loader_train = get_loader("mnist", "train")
loader_val = get_loader("mnist", "val")
loader_test = get_loader("mnist", "test")
data_loaders = {
    "train": loader_train,
    "val": loader_val,
    "test": loader_test
}

model = ResNet_18(1, 10, device=device, dtype=dtype)

learning_rate = 0.001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

num_epochs = 10

solver = Solver(model, data_loaders, optimizer, num_epochs, device=device)
solver.train()
solver.test()
# Out:
# epoch: 1/10	batch: 0/430	loss: 3.434556
# epoch: 1/10	batch: 100/430	loss: 0.216877
# epoch: 1/10	batch: 200/430	loss: 0.032683
# epoch: 1/10	batch: 300/430	loss: 0.094904
# epoch: 1/10	batch: 400/430	loss: 0.111746
# val accuracy: 98.16%	time elapsed: 00:00:23
# epoch: 2/10	batch: 0/430	loss: 0.021860
# epoch: 2/10	batch: 100/430	loss: 0.004230
# epoch: 2/10	batch: 200/430	loss: 0.100306
# epoch: 2/10	batch: 300/430	loss: 0.097123
# epoch: 2/10	batch: 400/430	loss: 0.013726
# val accuracy: 98.28%	time elapsed: 00:00:52
# epoch: 3/10	batch: 0/430	loss: 0.017221
# epoch: 3/10	batch: 100/430	loss: 0.086805
# epoch: 3/10	batch: 200/430	loss: 0.082990
# epoch: 3/10	batch: 300/430	loss: 0.024416
# epoch: 3/10	batch: 400/430	loss: 0.048099
# val accuracy: 98.74%	time elapsed: 00:01:22
# epoch: 4/10	batch: 0/430	loss: 0.008928
# epoch: 4/10	batch: 100/430	loss: 0.021654
# epoch: 4/10	batch: 200/430	loss: 0.048867
# epoch: 4/10	batch: 300/430	loss: 0.015813
# ...
